# %%
import xarray as xr
import matplotlib.pyplot as plt

# %% [markdown]
# # Visualise composites

# %%
path = '/Data/skd/scratch/innag3580/comp/composites/'
ds = xr.open_dataset(path + 'Above_combined_TEMP_3.0_40_20.nc')

# %%
ds.TEMP.isel(z_t=0, nlat=340, nlon=230).plot()
